# %%
mydatatest = {
    'cars': ["BMW", "GTR", "Ford"],
    'passings': [1, 2, 3]
}

myvar = pd.DataFrame(mydatatest)

print(myvar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       1 mydatatest = {
#       2     'cars': ["BMW", "GTR", "Ford"],
#       3     'passings': [1, 2, 3]
#       4 }
# ----> 6 myvar = pd.DataFrame("mydatatest")
#       8 print(myvar)
#
# NameError: name 'pd' is not defined

# %%
a = [1, 2, 3]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('gender_submission.csv')
df = pd.read_csv('test.csv')
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.head(3)
#
# NameError: name 'df' is not defined

# %%
print(type(df))
print(len(df['Age']))
print(type(df['Age']))
df['Age']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 891
# <class 'pandas.core.series.Series'>
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
print(df.loc[2])
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
new_df = df.dropna()
print(new_df.shape)
# Out:
# (183, 12)

# %%
df.fillna(130, inplace = True)
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00     0        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   0.0      1      2  W./C. 6607  23.45     0        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75     0        Q

# %%
df["Age"].median()
# Out:
# 24.0

# %%
df["Age"].mode()
# Out:
# 0    0.0
# Name: Age, dtype: float64

# %%
df['Age']==19
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df["Sex"].duplicated()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.plot()
#
# NameError: name 'df' is not defined

# %%
df.plot(kind = 'scatter',
       x = 'Fare',
       y = 'Ticket')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.plot(kind = 'scatter',
#       2        x = 'Fare',
#       3        y = 'Ticket')
#
# NameError: name 'df' is not defined

# %%
df['Age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
for x in df.index:
    if df.loc[x ,"Sex"] == 'female':
        df.loc[x ,"Sex"] = 0
    if df.loc[x ,"Sex"] == 'male':
        df.loc[x ,"Sex"] = 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0      1
# 2                               Heikkinen, Miss. Laina   0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0      1
# 4                             Allen, Mr. William Henry   1  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
df[df["Survived"] == 1]["Sex"].plot(kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df[df["Survived"] == 1]["Sex"].plot(kind = 'hist')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
# ...

# %%
df.to_csv('gender_submission_csv')

# %%
dict1 = {
    "country":["Brazil","Russia","India","China","South Africa"],
    "capital":["Brasilia","Moscow","New Delhi","beijing","Pretoria"],
    "area":[8.516,17.10,3.286,9.597,1.221],
    "population":[200.4,143.5,1252,1357,52.98]
}

# %%
import pandas as pd
brics = pd.DataFrame(dict1)
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1252.00
# 3         China    beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %%
import numpy as np
my_arrey = np.arrey([1, 5, 9, 13],
                   [2, 6, 10, 14],
                   [3, 7, 11, 15],
                   [4, 8, 12, 16])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 import numpy as np
# ----> 2 my_arrey = np.arrey([1, 5, 9, 13],
#       3                    [2, 6, 10, 14],
#       4                    [3, 7, 11, 15],
#       5                    [4, 8, 12, 16])
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrey'

# %%
my_df = pd.DataFram(my_arrey,
                   index = ["number1", "number2", "number3", "number4"],
                   colamns = ["Tehran", "Hamedan", "Dobey", "Tokyo"])
my_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 my_df = pd.DataFram(my_arrey,
#       2                    index = ["number1", "number2", "number3", "number4"],
#       3                    colamns = ["Tehran", "Hamedan", "Dobey", "Tokyo"])
#       4 my_df
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'DataFram'

# %%
my_df.index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 my_df.index()
#
# NameError: name 'my_df' is not defined

# %%
sns.boxplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['color'] = df['Sex']


df.color[df.Sex == 1] ='blue'
df.color[df.Sex == 0] ='red'

df.plot.scatter(x='SibSp',y = 'Sex', Sex = df['color'] )

plt.savefig('cyberoxi.png', format = 'png')
# Out:
# C:\Users\novin\AppData\Local\Temp\ipykernel_9104\3796721668.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.color[df.Sex == 1] ='blue'
# C:\Users\novin\AppData\Local\Temp\ipykernel_9104\3796721668.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.color[df.Sex == 0] ='red'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 7
#       4 df.color[df.Sex == 1] ='blue'
#       5 df.color[df.Sex == 0] ='red'
# ----> 7 df.plot.scatter(x='SibSp',y = 'Sex', Sex = df['color'] )
# ...

# %%
plt.scatter(x=df['PassengerId'], y=df["Age"])

# %%
df2 = df[['Age', 'Sex']]
df2
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

labels = 'women', 'man'
sizes = [df['Sex'].value_counts()[0],df['Sex'].value_counts()[1]]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2a99411a690>,
# ...
#  [Text(-0.4919454136803954, 0.9838646807152012, 'women'),
#   Text(0.4919455057964525, -0.9838646346559433, 'man')])

# %%
import matplotlib.pyplot as plt

labels = 'woman', 'man'
sizes = [df["Sex"].value_counts()[0], df['Sex'].value_counts()[1]]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2a996e16d90>,
# ...
#  [Text(-0.4919454136803954, 0.9838646807152012, 'woman'),
#   Text(0.4919455057964525, -0.9838646346559433, 'man')])

# %%
plt.figure(figsize=(12,5))

sns.scatterplot(x="PassengerId", y="Age", size="SibSp",
                palette="ch:r=+32 , d=.3",
                hue="Sex",
                sizes=(50,150), linewidth=1,edgecolor='k',data=df)
# Out:
# <Axes: xlabel='PassengerId', ylabel='Age'>

# %%
sns.boxplot(x=df["Sex"], y=df["Age"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=df["Sex"], y=df["Age"], data=df)
sns.swarmplot(x=df("Sex"), y=df["Age"], data=df, color="2.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 2
#       1 sns.boxplot(x=df["Sex"], y=df["Age"], data=df)
# ----> 2 sns.swarmplot(x=df("Sex"), y=df["Age"], data=df, color="2.")
#
# TypeError: 'DataFrame' object is not callable

# %%
sns.set(style="ticks")

sns.boxplot(x=df["Sex"], y=df["Age"], data=df)

sns.swarmplot(x=df["Sex"], y=df["Age"], data=df
              , size="2", color="3.", linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 4
#       1 sns.set(style="ticks")
#       3 sns.boxplot(x=df["Sex"], y=df["Age"], data=df)
# ----> 4 sns.swarmplot(x=df["Sex"], y=df["Age"], data=df
#       5               , size="2", color="3.", linewidth=1)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2660, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2656 if linewidth is None:
#    2657     linewidth = size / 10
#    2659 kwargs.update(dict(
# -> 2660     s=size ** 2,
#    2661     linewidth=linewidth,
#    2662 ))
#    2664 p.plot_swarms(
#    2665     dodge=dodge,
#    2666     color=color,
#    (...)
#    2669     plot_kws=kwargs,
#    2670 )
#    2672 p._add_axis_labels(ax)
#
# ...

# %%
sns.set(style="whitegrid", palette="pastel")


# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(x="Sex", y="Fare", hue="Pclass",
               split=False, inner="quart", data=df)

sns.despine(left=True)

# %%
plt.figure(figsize=(8,5))

ax = sns.violinplot(x="Sex", y="Fare", data=df)
ax = sns.swarmplot(x="Sex", y="Fare", data=df, color="black")
# Out:
# C:\Users\novin\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 50.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\novin\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\novin\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 61.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\novin\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 36.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(12,10), dpi= 80)

sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='BuPu', center=0, annot=True)

# Decorations
plt.title('Correlogram of patient', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# plt.show()
# Out:
# C:\Users\novin\AppData\Local\Temp\ipykernel_9104\526866239.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='BuPu', center=0, annot=True)
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  [Text(0, 0.5, 'PassengerId'),
#   Text(0, 1.5, 'Survived'),
#   Text(0, 2.5, 'Pclass'),
#   Text(0, 3.5, 'Age'),
#   Text(0, 4.5, 'SibSp'),
#   Text(0, 5.5, 'Parch'),
#   Text(0, 6.5, 'Fare')])

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df.corr(), annot=True , fmt=".2" ,linewidths=.1)
# Out:
# C:\Users\novin\AppData\Local\Temp\ipykernel_9104\1914994965.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), fmt=".2" ,linewidths=.1)
# <Axes: >

# %%
plt.figure(figsize=(12,10), dpi=70)
sns.heatmap(df.corr(), annot=True, color="red", linewidths=.1)
# Out:
# C:\Users\novin\AppData\Local\Temp\ipykernel_9104\885906690.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, color="red", linewidths=.1)
# <Axes: >

# %%
df['Age'].value_counts().head(40).plot(kind='barh', figsize=(10,15))
# Out:
# <Axes: >

# %%
sns.set(style="ticks")

sns.lmplot(x="Age", y="Fare", hue="Sex", data=df,
           palette="bright", scatter_kws={"s":30, "alpha":1})

# %%
sns.set(style="darkgrid")

sns.lineplot(x="Age", y="Fare", hue="Sex", data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.set(style="darkgrid")
#       3 sns.lineplot(x="Age", y="Fare", hue="Sex", data=df)
#
# NameError: name 'sns' is not defined

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, Ytrain, Ytest = train_test_split(x , y , test_size=0.3 , random_state=32)

print(Xtrain.shape)
print(Xtest.shape)

print(Ytrain.shape)
print(Ytest.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[183], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 Xtrain, Xtest, Ytrain, Ytest = train_test_split( y , test_size=0.3 , random_state=32)
#       5 print(Xtrain.shape)
#       6 print(Xtest.shape)
#
# NameError: name 'y' is not defined

# %%
pred_test = DT.predict(5, 6, 0, 3, "Moran", "Mr. James", "male", 0.0, 0, 0, 330877, 8.4583, 0, "Q")
pred_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 pred_test = DT.predict(5, 6, 0, 3, "Moran", "Mr. James", "male", 0.0, 0, 0, 330877, 8.4583, 0, "Q")
#       2 pred_test
#
# NameError: name 'DT' is not defined
