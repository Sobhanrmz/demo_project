# %%
import pandas as pd

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset) # تبدیل دیکشنری به دیتافریم

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
a = [1, 7, 2 ]
myvar = pd.Series(a) # تبدیل لیست به سری
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
df = pd.read_csv('heart data.csv') # خواندن فایل دیتاست csv
#print(type(df))
#print(df.to_string()) 
#print(df)
#print(df.shape)
df
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df.head(2)
# Out:
#    Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                 63    1           1           145.0         233.0
# 1                 37    1           3           130.0         250.0
#
#    blood sugar  electrocardiographic   heart rate  exercise induced  \
# 0          1.0                    2.0       150.0               0.0
# 1          0.0                    0.0       187.0               0.0
#
#    depression   slope   ca  thal  c
# 0          2.3    3.0  0.0   6.0  0
# 1          3.5    3.0  0.0   3.0  0

# %%
df.tail(2)
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# 595          0.0                    0.0       135.0               0.0
# 596          0.0                    0.0       122.0               0.0
#
#      depression   slope  ca  thal  c
# 595          0.0    NaN NaN   NaN  1
# 596          2.0    2.0 NaN   NaN  1

# %%
df
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
print(type(df))
print(len(df['cholestoral ']))
print(type(df['cholestoral ']))
df['cholestoral ']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 597
# <class 'pandas.core.series.Series'>
# 0      233.0
# 1      250.0
# 2      204.0
# 3      236.0
# 4      354.0
#        ...
# 592    266.0
# 593    288.0
# 594    336.0
# 595    491.0
# 596    222.0
# Name: cholestoral , Length: 597, dtype: float64

# %%
df.head() #پنج سطر اول
# Out:
#    Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                 63    1           1           145.0         233.0
# 1                 37    1           3           130.0         250.0
# 2                 41    0           2           130.0         204.0
# 3                 56    1           2           120.0         236.0
# 4                 57    0           4           120.0         354.0
#
#    blood sugar  electrocardiographic   heart rate  exercise induced  \
# 0          1.0                    2.0       150.0               0.0
# 1          0.0                    0.0       187.0               0.0
# 2          0.0                    2.0       172.0               0.0
# 3          0.0                    0.0       178.0               0.0
# 4          0.0                    0.0       163.0               1.0
#
#    depression   slope   ca  thal  c
# 0          2.3    3.0  0.0   6.0  0
# 1          3.5    3.0  0.0   3.0  0
# ...

# %%
df.tail() #پنج سطر آخر
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# 592          0.0                    0.0       134.0               1.0
# 593          0.0                    0.0       135.0               1.0
# 594          0.0                    0.0       118.0               1.0
# 595          0.0                    0.0       135.0               0.0
# 596          0.0                    0.0       122.0               0.0
#
#      depression   slope  ca  thal  c
# 592          2.0    2.0 NaN   NaN  1
# 593          2.0    2.0 NaN   NaN  1
# ...

# %%
df.tail(7) #هفت سطر آخر
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 590                 49    1           4           128.0         212.0
# 591                 50    1           4           140.0         231.0
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# 590          0.0                    0.0        96.0               1.0
# 591          0.0                    1.0       140.0               1.0
# 592          0.0                    0.0       134.0               1.0
# 593          0.0                    0.0       135.0               1.0
# ...

# %%
print(df.loc[0]) # location
# Out:
# Age (age in year)         63.0
# sex                        1.0
# chest pain                 1.0
# blood pressure           145.0
# cholestoral              233.0
# blood sugar                1.0
# electrocardiographic       2.0
# heart rate               150.0
# exercise induced           0.0
# depression                 2.3
# slope                      3.0
# ca                         0.0
# thal                       6.0
# c                          0.0
# Name: 0, dtype: float64

# %%
print(df.iloc[0]) # index location
# Out:
# Age (age in year)         63.0
# sex                        1.0
# chest pain                 1.0
# blood pressure           145.0
# cholestoral              233.0
# blood sugar                1.0
# electrocardiographic       2.0
# heart rate               150.0
# exercise induced           0.0
# depression                 2.3
# slope                      3.0
# ca                         0.0
# thal                       6.0
# c                          0.0
# Name: 0, dtype: float64

# %%
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
print(myvar.iloc[0])
print(myvar.loc["x"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 1
# 1

# %%
calories = {"day1": 420,"day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
new_df = df.dropna() # پاک کردن سطر هایی که حداقل یک فیلد خالی دارند
print(new_df.shape)
# Out:
# (298, 14)

# %%
df
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df.iloc[-5]
# Out:
# Age (age in year)         52.0
# sex                        1.0
# chest pain                 4.0
# blood pressure           140.0
# cholestoral              266.0
# blood sugar                0.0
# electrocardiographic       0.0
# heart rate               134.0
# exercise induced           1.0
# depression                 2.0
# slope                      2.0
# ca                         NaN
# thal                       NaN
# c                          1.0
# Name: 592, dtype: float64

# %%
df.fillna(130).iloc[-5]
# Out:
# Age (age in year)         52.0
# sex                        1.0
# chest pain                 4.0
# blood pressure           140.0
# cholestoral              266.0
# blood sugar                0.0
# electrocardiographic       0.0
# heart rate               134.0
# exercise induced           1.0
# depression                 2.0
# slope                      2.0
# ca                       130.0
# thal                     130.0
# c                          1.0
# Name: 592, dtype: float64

# %%
df.fillna(130, inplace = True)# پر کردن خالی ها با مقدار ثابت
df.tail()
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# 592          0.0                    0.0       134.0               1.0
# 593          0.0                    0.0       135.0               1.0
# 594          0.0                    0.0       118.0               1.0
# 595          0.0                    0.0       135.0               0.0
# 596          0.0                    0.0       122.0               0.0
#
#      depression   slope     ca   thal  c
# 592          2.0    2.0  130.0  130.0  1
# ...

# %%
df["sex"].fillna(0, inplace = True) # پر کردن مقادیر خالی با عدد صفر

# %%
df["sex"].mean() # میانگین یک فیلد از همه سطرها
# Out:
# 0.7018425460636516

# %%
df["chest pain"].median() # میانه
# Out:
# 3.0

# %%
df["chest pain"].mode() # مد
# Out:
# 0    4
# Name: chest pain, dtype: int64

# %%
df.loc[0, 'chest pain'] = 1000
df
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1        1000           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=597, step=1)

# %%
print(df.loc[0])
for x in df.index:
    if df.loc[x, "Age (age in year)"] > 60:
        df.loc[x, "Age (age in year)"] = 60
df
# Out:
# Age (age in year)          63.0
# sex                         1.0
# chest pain               1000.0
# blood pressure            145.0
# cholestoral               233.0
# blood sugar                 1.0
# electrocardiographic        2.0
# heart rate                150.0
# exercise induced            0.0
# depression                  2.3
# slope                       3.0
# ca                          0.0
# thal                        6.0
# c                           0.0
# Name: 0, dtype: float64
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   60    1        1000           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ...

# %%
df['sex']==1 # شرط
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 592     True
# 593     True
# 594     True
# 595     True
# 596     True
# Name: sex, Length: 597, dtype: bool

# %%
df[df['sex']==0] # فیلتر دیتافریم با شرط
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 2                   41    0           2           130.0         204.0
# 4                   57    0           4           120.0         354.0
# 6                   56    0           2           140.0         294.0
# 11                  48    0           3           130.0         275.0
# 14                  58    0           1           150.0         283.0
# ..                 ...  ...         ...             ...           ...
# 570                 60    0           4           150.0         225.0
# 573                 60    0           4           150.0         407.0
# 582                 54    0           3           130.0         294.0
# 583                 47    0           4           120.0         205.0
# 585                 58    0           2           180.0         393.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
for x in df.index:
    if df.loc[x, "sex"] != 0 and df.loc[x, "sex"] != 1:
        df.drop(x, inplace = True)

# %%
df.duplicated() # کدام سطر ها تکراری است؟
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 592    False
# 593    False
# 594    False
# 595    False
# 596    False
# Length: 597, dtype: bool

# %%
df[df.duplicated()] # فیلتر کردن دیتا فریم بر اساس داده های تکراری
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 265                 49    0           2           110.0         130.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# 265          0.0                    0.0       160.0               0.0
#
#      depression   slope     ca   thal  c
# 265          0.0  130.0  130.0  130.0  0

# %%
df.drop_duplicates(inplace = True) # پاک کردن سطر های تکراری 
df
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   60    1        1000           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df.corr() # بررسی همبستگی بین داده ها
# Out:
#                        Age (age in year)       sex  chest pain  \
# Age (age in year)               1.000000 -0.048620    0.053255
# sex                            -0.048620  1.000000    0.029489
# chest pain                      0.053255  0.029489    1.000000
# blood pressure                  0.244830  0.007694    0.030475
# cholestoral                     0.133351 -0.073816   -0.004834
# blood sugar                    -0.044854 -0.051047   -0.002557
# electrocardiographic            0.063054  0.020329    0.007182
# heart rate                     -0.311139 -0.085437    0.002090
# exercise induced                0.002241 -0.050009   -0.004286
# depression                      0.256654  0.093978    0.063577
# slope                          -0.342885  0.017299   -0.032870
# ca                             -0.339325  0.059204   -0.043052
# thal                           -0.302037  0.045128   -0.038480
# c                               0.227863  0.266879   -0.023374
#
# ...

# %%
df.loc[0 , "chest pain"] = 2

# %%
df.plot(kind = 'scatter',
        x = 'Age (age in year)',
        y = 'chest pain') # scatter
# Out:
# <Axes: xlabel='Age (age in year)', ylabel='chest pain'>

# %%
df["sex"].plot(kind = 'hist') # برای فراوانی داده ها histogram نمودار
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['c']==0]['sex'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df["c"] == 1]["sex"].plot(kind = 'hist') #  رسم هیستوگرام جنسیت افرادی که سکته کردند
# Out:
# <Axes: ylabel='Frequency'>

# %%
# and = &
# or = |

#df['chest pain'] >= 3
#df['c'] == 1

df[(df['chest pain'] >= 3)&(df['c'] == 1)] # دیتافریم کسانی که درد قفسه سینه بالای ۳ دارند و سکته کردند
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 352                 60    1           4           120.0         229.0
# 353                 53    1           4           140.0         203.0
# 356                 60    1           3           140.0         335.0
# 357                 57    1           4           150.0         276.0
# 358                 60    0           4           130.0         330.0
# ..                 ...  ...         ...             ...           ...
# 592                 52    1           4           140.0         266.0
# 593                 43    1           4           140.0         288.0
# 594                 41    1           4           120.0         336.0
# 595                 44    1           4           135.0         491.0
# 596                 49    1           4           150.0         222.0
#
#      blood sugar  electrocardiographic   heart rate  exercise induced  \
# ...

# %%
df[(df['c']==0) & (df['Age (age in year)'] >= 30) & (df['chest pain']>=3)]['sex'].plot(kind='hist') # رسم هیستوگرام جنسیت کسانی که سکته نکردند و سن بالای ۳۰ دارند و درد قفسه سینه بالای ۳ دارند
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv('heart data new.csv') # ذخیره csv
